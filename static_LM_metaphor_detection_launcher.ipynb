# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install datasets
# !pip install --upgrade gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.9/dist-packages (2.10.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (2.25.1)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.9/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets) (1.4.4)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.9/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from datasets) (0.13.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (6.0)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.9/dist-packages (from datasets) (2023.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from datasets) (23.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (22.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (3.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets) (1.8.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.9.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests>=2.19.0->datasets) (4.0.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gensim in /usr/local/lib/python3.9/dist-packages (4.3.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim) (6.3.0)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.10.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from gensim) (1.22.4)

# %%
#########
# Parameter --model, one of:
#    'word2vec-google-news-300'
#    'glove-wiki-gigaword-300'
#    'fasttext-wiki-news-subwords-300'

# !python static_LM_metaphor_detection_evaluate.py \
	--model 'word2vec-google-news-300'   \
	--metaphor_file '/path/to/mean_dataset'   \
    --dir_output_results 'res_static_LM/'
# Out:
# INFO:root:Downloading/loading the model
# INFO:gensim.models.keyedvectors:loading projection weights from /root/gensim-data/word2vec-google-news-300/word2vec-google-news-300.gz
# INFO:gensim.utils:KeyedVectors lifecycle event {'msg': 'loaded (3000000, 300) matrix of type float32 from /root/gensim-data/word2vec-google-news-300/word2vec-google-news-300.gz', 'binary': True, 'encoding': 'utf8', 'datetime': '2023-03-14T07:06:40.661724', 'gensim': '4.3.1', 'python': '3.9.16 (main, Dec  7 2022, 01:11:51) \n[GCC 9.4.0]', 'platform': 'Linux-5.10.147+-x86_64-with-glibc2.31', 'event': 'load_word2vec_format'}
# WARNING:datasets.builder:Found cached dataset csv (/root/.cache/huggingface/datasets/csv/default-679fe925952776dd/0.0.0/6b34fb8fcf56f7c8ba51dc895bfa2bfbe43546f190a60fcf74bb5e8afdcc2317)
# 100% 1/1 [00:00<00:00, 284.09it/s]
# INFO:root:Adding new words
# {'MetSource': 'ACTION', 'MetTarget': 'MOTION', 'SourceRole': 'actor', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'mover', 'SameFrameDifferentAttribute': 'redirecting', 'DiffFrameSameAtt': 'doctor', 'DiffFrameDiffAtt': 'sparkle'}
# {'MetSource': 'ANALYZING', 'MetTarget': 'DISSECTING', 'SourceRole': 'analyzer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'dissector', 'SameFrameDifferentAttribute': 'autopsy', 'DiffFrameSameAtt': 'chef', 'DiffFrameDiffAtt': 'math'}
# {'MetSource': 'ANALYZING', 'MetTarget': 'DISSECTING', 'SourceRole': 'object_of_analysis', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'dissected_entity', 'SameFrameDifferentAttribute': 'scalpel', 'DiffFrameSameAtt': 'model', 'DiffFrameDiffAtt': 'communication'}
# {'MetSource': 'ANALYZING', 'MetTarget': 'DISSECTING', 'SourceRole': 'analytic_conclusion', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'entity_in_pieces', 'SameFrameDifferentAttribute': 'lab', 'DiffFrameSameAtt': 'patchwork', 'DiffFrameDiffAtt': 'gaming'}
# {'MetSource': 'ANALYZING', 'MetTarget': 'DISSECTING', 'SourceRole': 'analytic_method', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'dissection_tool', 'SameFrameDifferentAttribute': 'body', 'DiffFrameSameAtt': 'developer_tool', 'DiffFrameDiffAtt': 'swimming_pool'}
# {'MetSource': 'ANGER', 'MetTarget': 'FIRE', 'SourceRole': 'anger', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'fire', 'SameFrameDifferentAttribute': 'hot', 'DiffFrameSameAtt': 'sadness', 'DiffFrameDiffAtt': 'corn'}
# {'MetSource': 'ANGER', 'MetTarget': 'FIRE', 'SourceRole': 'experiencer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'burning_object', 'SameFrameDifferentAttribute': 'lighter', 'DiffFrameSameAtt': 'patient', 'DiffFrameDiffAtt': 'gymnast'}
# {'MetSource': 'ANGER', 'MetTarget': 'FIRE', 'SourceRole': 'cause_of_anger', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'cause_of_fire', 'SameFrameDifferentAttribute': 'smoke', 'DiffFrameSameAtt': 'cause_of_divorce', 'DiffFrameDiffAtt': 'city'}
# {'MetSource': 'ANGER', 'MetTarget': 'FIRE', 'SourceRole': 'anger_level', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'fire_intensity', 'SameFrameDifferentAttribute': 'wood', 'DiffFrameSameAtt': 'flood_magnitude', 'DiffFrameDiffAtt': 'unicorn'}
# {'MetSource': 'ANGER', 'MetTarget': 'FIRE', 'SourceRole': 'mind_condition', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'burning_object_condition', 'SameFrameDifferentAttribute': 'combustion', 'DiffFrameSameAtt': 'economic_condition', 'DiffFrameDiffAtt': 'theatre'}
# {'MetSource': 'ANGER', 'MetTarget': 'FIRE', 'SourceRole': 'other_people', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'nearby_objects', 'SameFrameDifferentAttribute': 'flammable', 'DiffFrameSameAtt': 'acquaintance', 'DiffFrameDiffAtt': 'fat'}
# {'MetSource': 'ANGER', 'MetTarget': 'HEAT', 'SourceRole': 'anger_level', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'heat_level', 'SameFrameDifferentAttribute': 'boiling', 'DiffFrameSameAtt': 'difficulty_level', 'DiffFrameDiffAtt': 'university'}
# {'MetSource': 'ANGER', 'MetTarget': 'INSANITY', 'SourceRole': 'experiencer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'insane_person', 'SameFrameDifferentAttribute': 'hallucinating', 'DiffFrameSameAtt': 'student', 'DiffFrameDiffAtt': 'splash'}
# {'MetSource': 'ANGER', 'MetTarget': 'INSANITY', 'SourceRole': 'anger', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'insanity', 'SameFrameDifferentAttribute': 'insane_person', 'DiffFrameSameAtt': 'friendliness', 'DiffFrameDiffAtt': 'cow'}
# {'MetSource': 'ANGER', 'MetTarget': 'INSANITY', 'SourceRole': 'anger_level', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'agitation_level', 'SameFrameDifferentAttribute': 'manic', 'DiffFrameSameAtt': 'water_level', 'DiffFrameDiffAtt': 'tooth'}
# {'MetSource': 'ANGER', 'MetTarget': 'INSANITY', 'SourceRole': 'anger_limit', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'agitation_limit', 'SameFrameDifferentAttribute': 'delusion', 'DiffFrameSameAtt': 'speed_limit', 'DiffFrameDiffAtt': 'green'}
# {'MetSource': 'ANGER', 'MetTarget': 'INSANITY', 'SourceRole': 'angry_action', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'insane_behavior', 'SameFrameDifferentAttribute': 'asylum', 'DiffFrameSameAtt': 'heroic_act', 'DiffFrameDiffAtt': 'feather'}
# {'MetSource': 'ANGER', 'MetTarget': 'INSANITY', 'SourceRole': 'cause_of_anger', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'cause_of_insanity', 'SameFrameDifferentAttribute': 'treatment', 'DiffFrameSameAtt': 'cause_of_bankruptcy', 'DiffFrameDiffAtt': 'peanut_butter'}
# {'MetSource': 'ATTRIBUTES', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'posessor', 'SameFrameDifferentAttribute': 'possessive_person', 'DiffFrameSameAtt': 'criminal', 'DiffFrameDiffAtt': 'canadian'}
# {'MetSource': 'ATTRIBUTES', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'attribute', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'owner', 'DiffFrameSameAtt': 'consequence', 'DiffFrameDiffAtt': 'execute'}
# {'MetSource': 'BELIEFS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'belief', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'purchase', 'DiffFrameSameAtt': 'enjoyment', 'DiffFrameDiffAtt': 'definitive'}
# {'MetSource': 'BELIEFS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'believer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possessor', 'SameFrameDifferentAttribute': 'possessed_object', 'DiffFrameSameAtt': 'artisan', 'DiffFrameDiffAtt': 'nectar'}
# {'MetSource': 'BELIEFS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'belief_relation_status', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possess_relation_status', 'SameFrameDifferentAttribute': 'property', 'DiffFrameSameAtt': 'labour_relation_status', 'DiffFrameDiffAtt': 'battery'}
# {'MetSource': 'BELIEFS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'belief_relation', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession_relation', 'SameFrameDifferentAttribute': 'lose_possession', 'DiffFrameSameAtt': 'contractual_relation', 'DiffFrameDiffAtt': 'code'}
# {'MetSource': 'CHANGE', 'MetTarget': 'ACQUISITION', 'SourceRole': 'experiencer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'recipient', 'SameFrameDifferentAttribute': 'earn', 'DiffFrameSameAtt': 'employee', 'DiffFrameDiffAtt': 'bubble'}
# {'MetSource': 'CHANGE', 'MetTarget': 'ACQUISITION', 'SourceRole': 'final_state', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'buying', 'DiffFrameSameAtt': 'landing', 'DiffFrameDiffAtt': 'concert'}
# {'MetSource': 'CHANGE', 'MetTarget': 'LOSS', 'SourceRole': 'experiencer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'donor', 'SameFrameDifferentAttribute': 'voluntary', 'DiffFrameSameAtt': 'thinker', 'DiffFrameDiffAtt': 'blanket'}
# {'MetSource': 'CHANGE', 'MetTarget': 'LOSS', 'SourceRole': 'initial_state', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'lost_entity', 'DiffFrameSameAtt': 'deaparture', 'DiffFrameDiffAtt': 'basketball'}
# {'MetSource': 'COGNIZING', 'MetTarget': 'EATING', 'SourceRole': 'cognizer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'eater', 'SameFrameDifferentAttribute': 'food', 'DiffFrameSameAtt': 'adventurer', 'DiffFrameDiffAtt': 'candle'}
# {'MetSource': 'COMMUNICATING', 'MetTarget': 'GUIDING', 'SourceRole': 'communicator', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'leader', 'SameFrameDifferentAttribute': 'guiding_light', 'DiffFrameSameAtt': 'student', 'DiffFrameDiffAtt': 'carrot'}
# {'MetSource': 'COMMUNICATING', 'MetTarget': 'GUIDING', 'SourceRole': 'addressee', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'follower', 'SameFrameDifferentAttribute': 'reference', 'DiffFrameSameAtt': 'designer', 'DiffFrameDiffAtt': 'cherry'}
# {'MetSource': 'COMMUNICATING', 'MetTarget': 'SHOWING', 'SourceRole': 'communicator', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'shower', 'SameFrameDifferentAttribute': 'full_screen', 'DiffFrameSameAtt': 'chef', 'DiffFrameDiffAtt': 'chocolate'}
# {'MetSource': 'COMMUNICATING', 'MetTarget': 'SHOWING', 'SourceRole': 'addressee', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'seer', 'SameFrameDifferentAttribute': 'gallery', 'DiffFrameSameAtt': 'client', 'DiffFrameDiffAtt': 'cloud'}
# {'MetSource': 'COMMUNICATING', 'MetTarget': 'SHOWING', 'SourceRole': 'message', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object_seen', 'SameFrameDifferentAttribute': 'exhibitionist', 'DiffFrameSameAtt': 'present', 'DiffFrameDiffAtt': 'coffee'}
# {'MetSource': 'COMMUNICATING', 'MetTarget': 'SHOWING', 'SourceRole': 'communicator', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'perception_causer', 'SameFrameDifferentAttribute': 'binoculars', 'DiffFrameSameAtt': 'trigger', 'DiffFrameDiffAtt': 'disco'}
# {'MetSource': 'CONSCIOUS', 'MetTarget': 'UP', 'SourceRole': 'conscious_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'upright_entity', 'SameFrameDifferentAttribute': 'ascend', 'DiffFrameSameAtt': 'independent_entity', 'DiffFrameDiffAtt': 'compass'}
# {'MetSource': 'CONSCIOUS', 'MetTarget': 'UP', 'SourceRole': 'state_of_consciousness', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'state_of_uprightness', 'SameFrameDifferentAttribute': 'ladder', 'DiffFrameSameAtt': 'state_of_emergency', 'DiffFrameDiffAtt': 'computer'}
# {'MetSource': 'CONSCIOUSNESS', 'MetTarget': 'VERTICALITY', 'SourceRole': 'conscious_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'upright_entity', 'SameFrameDifferentAttribute': 'elevator', 'DiffFrameSameAtt': 'political_entity', 'DiffFrameDiffAtt': 'croissant'}
# {'MetSource': 'CONSCIOUSNESS', 'MetTarget': 'VERTICALITY', 'SourceRole': 'state_of_consciousness', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'state_of_uprightness', 'SameFrameDifferentAttribute': 'height', 'DiffFrameSameAtt': 'state_of_health', 'DiffFrameDiffAtt': 'cyclone'}
# {'MetSource': 'CONTROL', 'MetTarget': 'UP', 'SourceRole': 'controlling_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'higher_positioned_entity', 'SameFrameDifferentAttribute': 'vertigo', 'DiffFrameSameAtt': 'private_entity', 'DiffFrameDiffAtt': 'daisy'}
# {'MetSource': 'CORPORATIONS', 'MetTarget': 'PEOPLE', 'SourceRole': 'corporation', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'person', 'SameFrameDifferentAttribute': 'young', 'DiffFrameSameAtt': 'plant', 'DiffFrameDiffAtt': 'dance'}
# {'MetSource': 'CORPORATIONS', 'MetTarget': 'PEOPLE', 'SourceRole': 'rights_of_corporation', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'rights_of_person', 'SameFrameDifferentAttribute': 'inherit', 'DiffFrameSameAtt': 'rights_of_animal', 'DiffFrameDiffAtt': 'deer'}
# {'MetSource': 'CORRUPTION', 'MetTarget': 'DECAY', 'SourceRole': 'corrupt_activities', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'decaying_process', 'SameFrameDifferentAttribute': 'decaying_entity', 'DiffFrameSameAtt': 'disintegration', 'DiffFrameDiffAtt': 'diamond'}
# {'MetSource': 'CORRUPTION', 'MetTarget': 'DECAY', 'SourceRole': 'corruption_affectee', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'decayed_entity', 'SameFrameDifferentAttribute': 'constant', 'DiffFrameSameAtt': 'rotten_fruit', 'DiffFrameDiffAtt': 'drum'}
# {'MetSource': 'CORRUPTION', 'MetTarget': 'DECAY', 'SourceRole': 'corrupting_effect', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'decaying_effect', 'SameFrameDifferentAttribute': 'decay_cause', 'DiffFrameSameAtt': 'putrefaction', 'DiffFrameDiffAtt': 'duck'}
# {'MetSource': 'CORRUPTION', 'MetTarget': 'EROSION', 'SourceRole': 'corrupt_activities', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'eroding_process', 'SameFrameDifferentAttribute': 'eroding_agent', 'DiffFrameSameAtt': 'business', 'DiffFrameDiffAtt': 'elevator'}
# {'MetSource': 'CORRUPTION', 'MetTarget': 'EROSION', 'SourceRole': 'corruption_affectee', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'eroded_entity', 'SameFrameDifferentAttribute': 'sedimentation', 'DiffFrameSameAtt': 'imprisoned_person', 'DiffFrameDiffAtt': 'espresso'}
# {'MetSource': 'CORRUPTION', 'MetTarget': 'EROSION', 'SourceRole': 'corrupting_effect', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'eroding_effect', 'SameFrameDifferentAttribute': 'erosion_prevention', 'DiffFrameSameAtt': 'drug_effect', 'DiffFrameDiffAtt': 'fabric'}
# {'MetSource': 'DESIRE', 'MetTarget': 'HUNGER', 'SourceRole': 'desire', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'hunger', 'SameFrameDifferentAttribute': 'food', 'DiffFrameSameAtt': 'tension', 'DiffFrameDiffAtt': 'falcon'}
# {'MetSource': 'DESIRE', 'MetTarget': 'HUNGER', 'SourceRole': 'desirer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'hungry_person', 'SameFrameDifferentAttribute': 'malnutrition', 'DiffFrameSameAtt': 'addict', 'DiffFrameDiffAtt': 'fan'}
# {'MetSource': 'DESIRE', 'MetTarget': 'HUNGER', 'SourceRole': 'desired_object', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object_hungered_for', 'SameFrameDifferentAttribute': 'stomach', 'DiffFrameSameAtt': 'distant_object', 'DiffFrameDiffAtt': 'flag'}
# {'MetSource': 'ELECTION', 'MetTarget': 'WAR', 'SourceRole': 'candidate1', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'war.side1', 'SameFrameDifferentAttribute': 'weapon', 'DiffFrameSameAtt': 'colleague1', 'DiffFrameDiffAtt': 'map'}
# {'MetSource': 'ELECTION', 'MetTarget': 'WAR', 'SourceRole': 'candidate2', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'war.side2', 'SameFrameDifferentAttribute': 'battle_field', 'DiffFrameSameAtt': 'colleague2', 'DiffFrameDiffAtt': 'nocturnal'}
# {'MetSource': 'EMOTIONS', 'MetTarget': 'OBJECTS', 'SourceRole': 'directed_emotion', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object', 'SameFrameDifferentAttribute': 'object_representation', 'DiffFrameSameAtt': 'invention', 'DiffFrameDiffAtt': 'author'}
# {'MetSource': 'EMOTIONS', 'MetTarget': 'SUBSTANCES', 'SourceRole': 'emotions', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'substances', 'SameFrameDifferentAttribute': 'substance_processing', 'DiffFrameSameAtt': 'people', 'DiffFrameDiffAtt': 'admire'}
# {'MetSource': 'EMOTIONS', 'MetTarget': 'SUBSTANCES', 'SourceRole': 'body', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'container_for_substances', 'SameFrameDifferentAttribute': 'substance_use', 'DiffFrameSameAtt': 'landscape', 'DiffFrameDiffAtt': 'agreement'}
# {'MetSource': 'FORCES', 'MetTarget': 'OBJECTS', 'SourceRole': 'force', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object_entity', 'SameFrameDifferentAttribute': 'object_representation', 'DiffFrameSameAtt': 'soldier', 'DiffFrameDiffAtt': 'closure'}
# {'MetSource': 'FORCES', 'MetTarget': 'OBJECTS', 'SourceRole': 'force_amount', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'size', 'SameFrameDifferentAttribute': 'color', 'DiffFrameSameAtt': 'temperature', 'DiffFrameDiffAtt': 'training'}
# {'MetSource': 'FUNCTIONALITY', 'MetTarget': 'VERTICALITY', 'SourceRole': 'functionality_scale', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'verticality_scale', 'SameFrameDifferentAttribute': 'standing', 'DiffFrameSameAtt': 'singing_scale', 'DiffFrameDiffAtt': 'benevolence'}
# {'MetSource': 'FUNCTIONALITY', 'MetTarget': 'VERTICALITY', 'SourceRole': 'functional_status', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'scalar_position', 'SameFrameDifferentAttribute': 'leap', 'DiffFrameSameAtt': 'political_role', 'DiffFrameDiffAtt': 'brevity'}
# {'MetSource': 'FUNCTIONALITY', 'MetTarget': 'VERTICALITY', 'SourceRole': 'functional_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'vertical_entity', 'SameFrameDifferentAttribute': 'tall', 'DiffFrameSameAtt': 'living_entity', 'DiffFrameDiffAtt': 'defeat'}
# {'MetSource': 'GROUPS', 'MetTarget': 'CONTAINERS', 'SourceRole': 'group', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'container', 'SameFrameDifferentAttribute': 'material', 'DiffFrameSameAtt': 'network', 'DiffFrameDiffAtt': 'dilligence'}
# {'MetSource': 'GROUPS', 'MetTarget': 'CONTAINERS', 'SourceRole': 'members', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'contents', 'SameFrameDifferentAttribute': 'shape', 'DiffFrameSameAtt': 'musical_notes', 'DiffFrameDiffAtt': 'critic'}
# {'MetSource': 'GROUPS', 'MetTarget': 'POSSESSORS', 'SourceRole': 'group', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possessor', 'SameFrameDifferentAttribute': 'possesed_object', 'DiffFrameSameAtt': 'organ', 'DiffFrameDiffAtt': 'free'}
# {'MetSource': 'GROUPS', 'MetTarget': 'POSSESSORS', 'SourceRole': 'members', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'facts', 'DiffFrameSameAtt': 'facts', 'DiffFrameDiffAtt': 'flexible'}
# {'MetSource': 'GUNS', 'MetTarget': 'DRUGS', 'SourceRole': 'weapon', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'addicting_thing', 'SameFrameDifferentAttribute': 'side_effect', 'DiffFrameSameAtt': 'tool', 'DiffFrameDiffAtt': 'fortunate'}
# {'MetSource': 'GUNS', 'MetTarget': 'MAGICAL', 'SourceRole': 'weapon', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'magical_object', 'SameFrameDifferentAttribute': 'wizard', 'DiffFrameSameAtt': 'sports_machine', 'DiffFrameDiffAtt': 'heated'}
# {'MetSource': 'GUNS', 'MetTarget': 'MAGICAL', 'SourceRole': 'weapon', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'magical_object', 'SameFrameDifferentAttribute': 'make_magic', 'DiffFrameSameAtt': 'shield', 'DiffFrameDiffAtt': 'focused'}
# {'MetSource': 'GUNS', 'MetTarget': 'PESTS', 'SourceRole': 'weapon', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'pest', 'SameFrameDifferentAttribute': 'exterminator', 'DiffFrameSameAtt': 'body_part', 'DiffFrameDiffAtt': 'hourly'}
# {'MetSource': 'HEALTH', 'MetTarget': 'VERTICALITY', 'SourceRole': 'healthy_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'upright_entity', 'SameFrameDifferentAttribute': 'elevation', 'DiffFrameSameAtt': 'mysterious_entity', 'DiffFrameDiffAtt': 'habit'}
# {'MetSource': 'HEALTH', 'MetTarget': 'VERTICALITY', 'SourceRole': 'state_of_health', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'state_of_uprightness', 'SameFrameDifferentAttribute': 'step', 'DiffFrameSameAtt': 'wealthy_person', 'DiffFrameDiffAtt': 'hatred'}
# {'MetSource': 'IDEAS', 'MetTarget': 'FOOD', 'SourceRole': 'idea_self', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'food', 'SameFrameDifferentAttribute': 'buffet', 'DiffFrameSameAtt': 'money', 'DiffFrameDiffAtt': 'gesture'}
# {'MetSource': 'IDEAS', 'MetTarget': 'FOOD', 'SourceRole': 'idea_cognizer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'food_consumer', 'SameFrameDifferentAttribute': 'dinner', 'DiffFrameSameAtt': 'pilot', 'DiffFrameDiffAtt': 'imply'}
# {'MetSource': 'IDEAS', 'MetTarget': 'OBJECTS', 'SourceRole': 'idea_self', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object_entity', 'SameFrameDifferentAttribute': 'object_design', 'DiffFrameSameAtt': 'dust', 'DiffFrameDiffAtt': 'hammer'}
# {'MetSource': 'IDEAS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'idea_cognizer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possessor', 'SameFrameDifferentAttribute': 'gain_possession', 'DiffFrameSameAtt': 'profet', 'DiffFrameDiffAtt': 'happy'}
# {'MetSource': 'IDEAS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'idea_self', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'lose_possession', 'DiffFrameSameAtt': 'hazard', 'DiffFrameDiffAtt': 'future'}
# {'MetSource': 'IMPORTANCE', 'MetTarget': 'SIZE', 'SourceRole': 'entity_evaluated_for_importance', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'entity', 'SameFrameDifferentAttribute': 'increase_size', 'DiffFrameSameAtt': 'television', 'DiffFrameDiffAtt': 'graceful'}
# {'MetSource': 'IMPORTANCE', 'MetTarget': 'SIZE', 'SourceRole': 'degree_of_importance', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'scalar_position', 'SameFrameDifferentAttribute': 'entity_size', 'DiffFrameSameAtt': 'measure_of_quantity', 'DiffFrameDiffAtt': 'horrific'}
# {'MetSource': 'IMPORTANCE', 'MetTarget': 'SIZE', 'SourceRole': 'importance_scale', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'size_scale', 'SameFrameDifferentAttribute': 'measure', 'DiffFrameSameAtt': 'quantity_scale', 'DiffFrameDiffAtt': 'innocent'}
# {'MetSource': 'KNOWING', 'MetTarget': 'PERCEIVING', 'SourceRole': 'knower', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'perceiver', 'SameFrameDifferentAttribute': 'event_happening', 'DiffFrameSameAtt': 'crazy_person', 'DiffFrameDiffAtt': 'impact'}
# {'MetSource': 'KNOWING', 'MetTarget': 'PERCEIVING', 'SourceRole': 'mind', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'faculty', 'SameFrameDifferentAttribute': 'object_to_percieve', 'DiffFrameSameAtt': 'soul', 'DiffFrameDiffAtt': 'child'}
# {'MetSource': 'KNOWING', 'MetTarget': 'PERCEIVING', 'SourceRole': 'knowledge', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'perceived_thing', 'SameFrameDifferentAttribute': 'percieving_agent', 'DiffFrameSameAtt': 'time', 'DiffFrameDiffAtt': 'funny'}
# {'MetSource': 'KNOWING', 'MetTarget': 'SEEING', 'SourceRole': 'knower', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'seer', 'SameFrameDifferentAttribute': 'blindness', 'DiffFrameSameAtt': 'hard_worker', 'DiffFrameDiffAtt': 'creepy'}
# {'MetSource': 'KNOWING', 'MetTarget': 'SEEING', 'SourceRole': 'mind', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'eyes', 'SameFrameDifferentAttribute': 'glasses', 'DiffFrameSameAtt': 'heart', 'DiffFrameDiffAtt': 'shout'}
# {'MetSource': 'KNOWING', 'MetTarget': 'SEEING', 'SourceRole': 'knowledge_capacity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'visual_ability', 'SameFrameDifferentAttribute': 'unseen', 'DiffFrameSameAtt': 'patiente', 'DiffFrameDiffAtt': 'inefficient'}
# {'MetSource': 'KNOWING', 'MetTarget': 'SEEING', 'SourceRole': 'knowledge', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'seen_object', 'SameFrameDifferentAttribute': 'point_of_view', 'DiffFrameSameAtt': 'valuable_object', 'DiffFrameDiffAtt': 'inflation'}
# {'MetSource': 'KNOWING', 'MetTarget': 'TOUCHING', 'SourceRole': 'knower', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'toucher', 'SameFrameDifferentAttribute': 'skin', 'DiffFrameSameAtt': 'old_person', 'DiffFrameDiffAtt': 'help'}
# {'MetSource': 'KNOWING', 'MetTarget': 'TOUCHING', 'SourceRole': 'mind', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'limbs', 'SameFrameDifferentAttribute': 'soft', 'DiffFrameSameAtt': 'books', 'DiffFrameDiffAtt': 'charitable'}
# {'MetSource': 'KNOWING', 'MetTarget': 'TOUCHING', 'SourceRole': 'idea', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object', 'SameFrameDifferentAttribute': 'texture', 'DiffFrameSameAtt': 'culture', 'DiffFrameDiffAtt': 'apprentice'}
# {'MetSource': 'LAWS', 'MetTarget': 'PLANTS', 'SourceRole': 'law', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'plant_entity', 'SameFrameDifferentAttribute': 'seed', 'DiffFrameSameAtt': 'rock', 'DiffFrameDiffAtt': 'learning'}
# {'MetSource': 'LAWS', 'MetTarget': 'PLANTS', 'SourceRole': 'legal_actions', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'plant_attributes', 'SameFrameDifferentAttribute': 'garden', 'DiffFrameSameAtt': 'tactics', 'DiffFrameDiffAtt': 'icon'}
# {'MetSource': 'LAWS', 'MetTarget': 'PLANTS', 'SourceRole': 'law_creator', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'plant_nourishment', 'SameFrameDifferentAttribute': 'soil', 'DiffFrameSameAtt': 'head', 'DiffFrameDiffAtt': 'fundamental'}
# {'MetSource': 'LAWS', 'MetTarget': 'PLANTS', 'SourceRole': 'jurisdiction', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'plant_size', 'SameFrameDifferentAttribute': 'transplant', 'DiffFrameSameAtt': 'chess_board', 'DiffFrameDiffAtt': 'frugality'}
# {'MetSource': 'LEARNING', 'MetTarget': 'ACQUIRING', 'SourceRole': 'learner', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'recipient', 'SameFrameDifferentAttribute': 'price', 'DiffFrameSameAtt': 'lieutenant', 'DiffFrameDiffAtt': 'fascination'}
# {'MetSource': 'LEARNING', 'MetTarget': 'ACQUIRING', 'SourceRole': 'learned_material', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'trading', 'DiffFrameSameAtt': 'nutrients', 'DiffFrameDiffAtt': 'fearful'}
# {'MetSource': 'MACHINES', 'MetTarget': 'PEOPLE', 'SourceRole': 'machine', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'person', 'SameFrameDifferentAttribute': 'citizen', 'DiffFrameSameAtt': 'computer', 'DiffFrameDiffAtt': 'energetic'}
# {'MetSource': 'MACHINES', 'MetTarget': 'PEOPLE', 'SourceRole': 'machine_hardware', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'human_body', 'SameFrameDifferentAttribute': 'crowded', 'DiffFrameSameAtt': 'loom', 'DiffFrameDiffAtt': 'knife'}
# {'MetSource': 'MACHINES', 'MetTarget': 'PEOPLE', 'SourceRole': 'machine_software', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'human_mind', 'SameFrameDifferentAttribute': 'humanity', 'DiffFrameSameAtt': 'art', 'DiffFrameDiffAtt': 'fork'}
# {'MetSource': 'MACHINES', 'MetTarget': 'PEOPLE', 'SourceRole': 'good_functioning_of_machine', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'health_of_person', 'SameFrameDifferentAttribute': 'population', 'DiffFrameSameAtt': 'orginazed_army', 'DiffFrameDiffAtt': 'download'}
# {'MetSource': 'MORAL', 'MetTarget': 'STRAIGHT', 'SourceRole': 'moral_person', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'straight_person', 'SameFrameDifferentAttribute': 'straightening_process', 'DiffFrameSameAtt': 'boring_person', 'DiffFrameDiffAtt': 'hair'}
# {'MetSource': 'MORAL', 'MetTarget': 'STRAIGHT', 'SourceRole': 'moral_person', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'straight_person', 'SameFrameDifferentAttribute': 'straighten', 'DiffFrameSameAtt': 'happy_person', 'DiffFrameDiffAtt': 'desired_property'}
# {'MetSource': 'MORALITY', 'MetTarget': 'PURITY', 'SourceRole': 'moral_condition', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'pure_condition', 'SameFrameDifferentAttribute': 'purifying_treatment', 'DiffFrameSameAtt': 'subjective_condition', 'DiffFrameDiffAtt': 'heir'}
# {'MetSource': 'MORALITY', 'MetTarget': 'PURITY', 'SourceRole': 'moral_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'pure_entity', 'SameFrameDifferentAttribute': 'purification_process', 'DiffFrameSameAtt': 'valuable_entity', 'DiffFrameDiffAtt': 'kitten'}
# {'MetSource': 'MORALITY', 'MetTarget': 'STRAIGHTNESS', 'SourceRole': 'moral_person', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'straight_object', 'SameFrameDifferentAttribute': 'straightening_process', 'DiffFrameSameAtt': 'chain_element', 'DiffFrameDiffAtt': 'follower'}
# {'MetSource': 'MORALITY', 'MetTarget': 'STRAIGHTNESS', 'SourceRole': 'morality', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'property_of_being_straight', 'SameFrameDifferentAttribute': 'straightening_mechanism', 'DiffFrameSameAtt': 'wisdom', 'DiffFrameDiffAtt': 'discover'}
# {'MetSource': 'PROVING', 'MetTarget': 'SHOWING', 'SourceRole': 'reasoner', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'perception_causer', 'SameFrameDifferentAttribute': 'exhibition', 'DiffFrameSameAtt': 'judge', 'DiffFrameDiffAtt': 'diver'}
# {'MetSource': 'PURITY', 'MetTarget': 'CLEANLINESS', 'SourceRole': 'pure_substance', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'clean_substance', 'SameFrameDifferentAttribute': 'cleaning_tool', 'DiffFrameSameAtt': 'unttouched_substance', 'DiffFrameDiffAtt': 'sleep'}
# {'MetSource': 'PURITY', 'MetTarget': 'CLEANLINESS', 'SourceRole': 'substances', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'impurities', 'SameFrameDifferentAttribute': 'mop', 'DiffFrameSameAtt': 'infants', 'DiffFrameDiffAtt': 'whisper'}
# {'MetSource': 'QUANTITY', 'MetTarget': 'SIZE', 'SourceRole': 'quantity_scale', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'size_scale', 'SameFrameDifferentAttribute': 'measuring_tape', 'DiffFrameSameAtt': 'importance_scale', 'DiffFrameDiffAtt': 'kiss'}
# {'MetSource': 'QUANTITY', 'MetTarget': 'SIZE', 'SourceRole': 'measure_of_quantity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'scalar_position', 'SameFrameDifferentAttribute': 'ruler', 'DiffFrameSameAtt': 'degree_of_importance', 'DiffFrameDiffAtt': 'cheese'}
# {'MetSource': 'QUANTITY', 'MetTarget': 'SIZE', 'SourceRole': 'entity_amount', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'entity_size', 'SameFrameDifferentAttribute': 'measuring_scale', 'DiffFrameSameAtt': 'noise_frequency', 'DiffFrameDiffAtt': 'development_tools'}
# {'MetSource': 'QUANTITY', 'MetTarget': 'VERTICALITY', 'SourceRole': 'quantity_scale', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'verticality_scale', 'SameFrameDifferentAttribute': 'up', 'DiffFrameSameAtt': 'weight_scale', 'DiffFrameDiffAtt': 'faith'}
# {'MetSource': 'QUANTITY', 'MetTarget': 'VERTICALITY', 'SourceRole': 'measure_of_quantity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'scalar_position', 'SameFrameDifferentAttribute': 'going_upwards', 'DiffFrameSameAtt': 'grams', 'DiffFrameDiffAtt': 'fairness'}
# {'MetSource': 'RELATIONSHIPS', 'MetTarget': 'CONTAINERS', 'SourceRole': 'relationship', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'container', 'SameFrameDifferentAttribute': 'lid', 'DiffFrameSameAtt': 'journey', 'DiffFrameDiffAtt': 'slam'}
# {'MetSource': 'RELATIONSHIPS', 'MetTarget': 'CONTAINERS', 'SourceRole': 'relationship_participants', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'contents', 'SameFrameDifferentAttribute': 'container_shape', 'DiffFrameSameAtt': 'traveler', 'DiffFrameDiffAtt': 'kick'}
# {'MetSource': 'RELATIONSHIPS', 'MetTarget': 'OBJECTS', 'SourceRole': 'relation', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'object_entity', 'SameFrameDifferentAttribute': 'fill', 'DiffFrameSameAtt': 'path', 'DiffFrameDiffAtt': 'giggle'}
# {'MetSource': 'RIGHTS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'rights_holder', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possessor', 'SameFrameDifferentAttribute': 'own', 'DiffFrameSameAtt': 'responsible_person', 'DiffFrameDiffAtt': 'cough'}
# {'MetSource': 'RIGHTS', 'MetTarget': 'POSSESSIONS', 'SourceRole': 'right', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'possession_worth', 'DiffFrameSameAtt': 'weight', 'DiffFrameDiffAtt': 'single'}
# {'MetSource': 'RIGHTS', 'MetTarget': 'TERRITORIES', 'SourceRole': 'right', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'territory_whole', 'SameFrameDifferentAttribute': 'location', 'DiffFrameSameAtt': 'safety_mechanisms', 'DiffFrameDiffAtt': 'ultimate'}
# {'MetSource': 'RIGHTS', 'MetTarget': 'TERRITORIES', 'SourceRole': 'rights_holder', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'owner', 'SameFrameDifferentAttribute': 'map', 'DiffFrameSameAtt': 'benefitiary', 'DiffFrameDiffAtt': 'drag'}
# {'MetSource': 'SCALES', 'MetTarget': 'PATHS', 'SourceRole': 'minimal_value', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'source', 'SameFrameDifferentAttribute': 'incline', 'DiffFrameSameAtt': 'building_foundation', 'DiffFrameDiffAtt': 'king'}
# {'MetSource': 'SCALES', 'MetTarget': 'PATHS', 'SourceRole': 'intermediate_values', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'path', 'SameFrameDifferentAttribute': 'walkway', 'DiffFrameSameAtt': 'staircase_Steps', 'DiffFrameDiffAtt': 'shooting'}
# {'MetSource': 'SCALES', 'MetTarget': 'PATHS', 'SourceRole': 'maximal_value', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'goal', 'SameFrameDifferentAttribute': 'direction', 'DiffFrameSameAtt': 'up', 'DiffFrameDiffAtt': 'redesign'}
# {'MetSource': 'SCALES', 'MetTarget': 'PATHS', 'SourceRole': 'norm', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'landmark', 'SameFrameDifferentAttribute': 'detour', 'DiffFrameSameAtt': 'body', 'DiffFrameDiffAtt': 'step_up'}
# {'MetSource': 'SCALES', 'MetTarget': 'PATHS', 'SourceRole': 'position_on_scale', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'trajectory', 'SameFrameDifferentAttribute': 'mile', 'DiffFrameSameAtt': 'growth_stage', 'DiffFrameDiffAtt': 'imagination'}
# {'MetSource': 'SEEING', 'MetTarget': 'TOUCHING', 'SourceRole': 'eyes', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'touch_bodypart', 'SameFrameDifferentAttribute': 'touchy', 'DiffFrameSameAtt': 'mind', 'DiffFrameDiffAtt': 'laugh'}
# {'MetSource': 'SEEING', 'MetTarget': 'TOUCHING', 'SourceRole': 'visual_ability', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'sense_of_touch', 'SameFrameDifferentAttribute': 'skin', 'DiffFrameSameAtt': 'empathy', 'DiffFrameDiffAtt': 'fireman'}
# {'MetSource': 'SEEING', 'MetTarget': 'TOUCHING', 'SourceRole': 'seen_object', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'touched_thing', 'SameFrameDifferentAttribute': 'tactile', 'DiffFrameSameAtt': 'understood_person', 'DiffFrameDiffAtt': 'cuddle'}
# {'MetSource': 'SEEING', 'MetTarget': 'TOUCHING', 'SourceRole': 'visual_input', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'tactile_input', 'SameFrameDifferentAttribute': 'tact', 'DiffFrameSameAtt': 'cue', 'DiffFrameDiffAtt': 'printable'}
# {'MetSource': 'SEEING', 'MetTarget': 'TOUCHING', 'SourceRole': 'seer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'toucher', 'SameFrameDifferentAttribute': 'touch', 'DiffFrameSameAtt': 'controller', 'DiffFrameDiffAtt': 'red'}
# {'MetSource': 'SELECTION', 'MetTarget': 'ADOPTION', 'SourceRole': 'selector', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'family_representative', 'SameFrameDifferentAttribute': 'child', 'DiffFrameSameAtt': 'filter', 'DiffFrameDiffAtt': 'surfing'}
# {'MetSource': 'SELECTION', 'MetTarget': 'ADOPTION', 'SourceRole': 'options', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'candidates', 'SameFrameDifferentAttribute': 'orphanage', 'DiffFrameSameAtt': 'contestants', 'DiffFrameDiffAtt': 'building'}
# {'MetSource': 'SELECTION', 'MetTarget': 'ADOPTION', 'SourceRole': 'selection_option', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'adoptee', 'SameFrameDifferentAttribute': 'agency', 'DiffFrameSameAtt': 'menu_dish', 'DiffFrameDiffAtt': 'conclude'}
# {'MetSource': 'SICKNESS', 'MetTarget': 'DOWN', 'SourceRole': 'sick_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'supine_entity', 'SameFrameDifferentAttribute': 'descent', 'DiffFrameSameAtt': 'poor_individual', 'DiffFrameDiffAtt': 'adapt'}
# {'MetSource': 'STATES', 'MetTarget': 'LOCATIONS', 'SourceRole': 'profiled_state_value', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'profiled_region', 'SameFrameDifferentAttribute': 'direction', 'DiffFrameSameAtt': 'stock_value', 'DiffFrameDiffAtt': 'despise'}
# {'MetSource': 'STATES', 'MetTarget': 'LOCATIONS', 'SourceRole': 'standard', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'landmark', 'SameFrameDifferentAttribute': 'find', 'DiffFrameSameAtt': 'stock_exchange', 'DiffFrameDiffAtt': 'concentration'}
# {'MetSource': 'STATES', 'MetTarget': 'LOCATIONS', 'SourceRole': 'state_type', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'background', 'SameFrameDifferentAttribute': 'lost', 'DiffFrameSameAtt': 'brand', 'DiffFrameDiffAtt': 'depict'}
# {'MetSource': 'STATES', 'MetTarget': 'LOCATIONS', 'SourceRole': 'state_holder', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'trajector', 'SameFrameDifferentAttribute': 'zone', 'DiffFrameSameAtt': 'influencer', 'DiffFrameDiffAtt': 'dread'}
# {'MetSource': 'SUBJUGATION', 'MetTarget': 'DOWN', 'SourceRole': 'subjugated_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'vertically_lower_entity', 'SameFrameDifferentAttribute': 'falling_object', 'DiffFrameSameAtt': 'disempowered_entity', 'DiffFrameDiffAtt': 'wasted'}
# {'MetSource': 'TAXATION', 'MetTarget': 'PUNISHMENT', 'SourceRole': 'taxer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'punisher', 'SameFrameDifferentAttribute': 'prison', 'DiffFrameSameAtt': 'vampire', 'DiffFrameDiffAtt': 'amusement'}
# {'MetSource': 'TAXATION', 'MetTarget': 'PUNISHMENT', 'SourceRole': 'tax_payer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'punished_person', 'SameFrameDifferentAttribute': 'discipline', 'DiffFrameSameAtt': 'prey', 'DiffFrameDiffAtt': 'educate'}
# {'MetSource': 'TAXATION', 'MetTarget': 'PUNISHMENT', 'SourceRole': 'tax', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'punishment', 'SameFrameDifferentAttribute': 'punishment_justification', 'DiffFrameSameAtt': 'consequence', 'DiffFrameDiffAtt': 'comprehend'}
# {'MetSource': 'TAXATION', 'MetTarget': 'SLAVERY', 'SourceRole': 'taxer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'subjugator', 'SameFrameDifferentAttribute': 'freedom', 'DiffFrameSameAtt': 'dictator', 'DiffFrameDiffAtt': 'enchant'}
# {'MetSource': 'TAXATION', 'MetTarget': 'SLAVERY', 'SourceRole': 'tax_payer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'subjugated', 'SameFrameDifferentAttribute': 'slave', 'DiffFrameSameAtt': 'tortured_person', 'DiffFrameDiffAtt': 'nurture'}
# {'MetSource': 'TAXATION', 'MetTarget': 'THEFT', 'SourceRole': 'taxer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'thief', 'SameFrameDifferentAttribute': 'stolen_object', 'DiffFrameSameAtt': 'policeforce', 'DiffFrameDiffAtt': 'assist'}
# {'MetSource': 'TAXATION', 'MetTarget': 'THEFT', 'SourceRole': 'tax_payer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'victim', 'SameFrameDifferentAttribute': 'punishment', 'DiffFrameSameAtt': 'civilian', 'DiffFrameDiffAtt': 'frighten'}
# {'MetSource': 'TAXATION', 'MetTarget': 'THEFT', 'SourceRole': 'tax', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'stolen_item', 'SameFrameDifferentAttribute': 'stolen_object_value', 'DiffFrameSameAtt': 'justice', 'DiffFrameDiffAtt': 'compete'}
# {'MetSource': 'TAXES', 'MetTarget': 'DISEASES', 'SourceRole': 'tax_payer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'patient', 'SameFrameDifferentAttribute': 'cure', 'DiffFrameSameAtt': 'victim', 'DiffFrameDiffAtt': 'chuckle'}
# {'MetSource': 'TAXES', 'MetTarget': 'DISEASES', 'SourceRole': 'tax', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'disease', 'SameFrameDifferentAttribute': 'hospital', 'DiffFrameSameAtt': 'duty', 'DiffFrameDiffAtt': 'ascertain'}
# {'MetSource': 'TAXES', 'MetTarget': 'DUES', 'SourceRole': 'tax_payer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'member', 'SameFrameDifferentAttribute': 'due_date', 'DiffFrameSameAtt': 'weak_person', 'DiffFrameDiffAtt': 'rectify'}
# {'MetSource': 'TAXES', 'MetTarget': 'DUES', 'SourceRole': 'tax_payment', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'membership_fee', 'SameFrameDifferentAttribute': 'overdue', 'DiffFrameSameAtt': 'plot_twist', 'DiffFrameDiffAtt': 'simple'}
# {'MetSource': 'THEORIES', 'MetTarget': 'BUILDINGS', 'SourceRole': 'theoretical_domain', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'building_whole', 'SameFrameDifferentAttribute': 'building_material', 'DiffFrameSameAtt': 'ecosystem', 'DiffFrameDiffAtt': 'apple'}
# {'MetSource': 'THEORIES', 'MetTarget': 'BUILDINGS', 'SourceRole': 'theoretical_arguments', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'building_parts', 'SameFrameDifferentAttribute': 'building_design', 'DiffFrameSameAtt': 'branches', 'DiffFrameDiffAtt': 'branding'}
# {'MetSource': 'THEORIES', 'MetTarget': 'BUILDINGS', 'SourceRole': 'theory_supporting_evidence', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'building_foundation', 'SameFrameDifferentAttribute': 'architect', 'DiffFrameSameAtt': 'roots', 'DiffFrameDiffAtt': 'resurrect'}
# {'MetSource': 'THINKING', 'MetTarget': 'SPEAKING', 'SourceRole': 'cognizer', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'speaker', 'SameFrameDifferentAttribute': 'voice', 'DiffFrameSameAtt': 'artist', 'DiffFrameDiffAtt': 'validation'}
# {'MetSource': 'TIME', 'MetTarget': 'MONEY', 'SourceRole': 'duration', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'amount', 'SameFrameDifferentAttribute': 'save', 'DiffFrameSameAtt': 'distance', 'DiffFrameDiffAtt': 'visual'}
# {'MetSource': 'UNCONSCIOUS', 'MetTarget': 'DOWN', 'SourceRole': 'unconscious_entity', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'supine_entity', 'SameFrameDifferentAttribute': 'slide', 'DiffFrameSameAtt': 'brainless_entity', 'DiffFrameDiffAtt': 'unification'}
# {'MetSource': 'UNDERSTANDING', 'MetTarget': 'GRASPING', 'SourceRole': 'understanding_person', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'grasping_person', 'SameFrameDifferentAttribute': 'strength', 'DiffFrameSameAtt': 'seeing_person', 'DiffFrameDiffAtt': 'synchronize'}
# {'MetSource': 'UNDERSTANDING', 'MetTarget': 'GRASPING', 'SourceRole': 'understood_idea', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'grasped_object', 'SameFrameDifferentAttribute': 'pull', 'DiffFrameSameAtt': 'seen_object', 'DiffFrameDiffAtt': 'harmony'}
# {'MetSource': 'VOTING', 'MetTarget': 'SPEAKING', 'SourceRole': 'voter', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'speaker', 'SameFrameDifferentAttribute': 'tone', 'DiffFrameSameAtt': 'harvester', 'DiffFrameDiffAtt': 'dress'}
# {'MetSource': 'WHOLES', 'MetTarget': 'CONTAINERS', 'SourceRole': 'whole', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'container', 'SameFrameDifferentAttribute': 'store', 'DiffFrameSameAtt': 'world', 'DiffFrameDiffAtt': 'testify'}
# {'MetSource': 'WHOLES', 'MetTarget': 'CONTAINERS', 'SourceRole': 'parts', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'contents', 'SameFrameDifferentAttribute': 'empty', 'DiffFrameSameAtt': 'regions', 'DiffFrameDiffAtt': 'transcriber'}
# {'MetSource': 'WHOLES', 'MetTarget': 'POSSESSORS', 'SourceRole': 'whole', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possessor', 'SameFrameDifferentAttribute': 'ownership', 'DiffFrameSameAtt': 'person', 'DiffFrameDiffAtt': 'write'}
# {'MetSource': 'WHOLES', 'MetTarget': 'POSSESSORS', 'SourceRole': 'parts', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possession', 'SameFrameDifferentAttribute': 'object_value', 'DiffFrameSameAtt': 'personality_traits', 'DiffFrameDiffAtt': 'bloom'}
# {'MetSource': 'WHOLES', 'MetTarget': 'POSSESSORS', 'SourceRole': 'whole-part_relation', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'possess_relation', 'SameFrameDifferentAttribute': 'possession_time', 'DiffFrameSameAtt': 'geographic_relations', 'DiffFrameDiffAtt': 'fisherman'}
# {'MetSource': 'WORDS', 'MetTarget': 'CONTAINERS', 'SourceRole': 'word_form', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'container', 'SameFrameDifferentAttribute': 'enclosed', 'DiffFrameSameAtt': 'jewels', 'DiffFrameDiffAtt': 'desperate'}
# {'MetSource': 'WORDS', 'MetTarget': 'CONTAINERS', 'SourceRole': 'word_meaning', 'TargetRole (Gold) SameFrame as MetTarget and SameAtt as Source Role': 'contents', 'SameFrameDifferentAttribute': 'outside', 'DiffFrameSameAtt': 'soul', 'DiffFrameDiffAtt': 'intersect'}
# INFO:root:Finished: Adding new words
# INFO:root:Calculating fake words (one fake word for each metaphor in the dataset)
# INFO:root:Calculating results
# Creating CSV from Arrow format: 100% 1/1 [00:00<00:00, 11.89ba/s]
